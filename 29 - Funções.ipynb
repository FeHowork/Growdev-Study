# %% [markdown]
# ![Growdev](https://www.growdev.com.br/assets/images/logo_growdev.png)

# %% [markdown]
# Exercícios

# %% [markdown]
# Escreva uma função chamada soma que recebe dois números como argumentos e retorna a soma desses números. Em seguida, chame a função e imprima o resultado.

# %%
def soma(v1,v2):
    v1 = int(input('Digite o número 1: '))
    v2 = int(input('Digite o número 2: '))
    return v1 + v2
s = soma (v1,v2)

print('A soma dos números é: ', s)
# Out:
# A soma dos números é:  3

# %% [markdown]
# Escreva uma função chamada fatorial que recebe um número inteiro positivo como argumento e retorna o fatorial desse número.

# %%
fatorial = int(input('Digite o número a ser calculado fatorial'))
resultado = 1
for i in range(1, fatorial + 1):
    resultado *= i
        
def fator(fatorial):
    return resultado

fator(fatorial)
resultado

print(f'O fatorial de {i} é {resultado}')
# Out:
# O fatorial de 12 é 479001600

# %% [markdown]
# Escreva uma função chamada conta_vogais que recebe uma string como argumento e retorna a quantidade de vogais presentes na string.

# %%
palavra = input('Digite uma palavra: ')
a = (palavra).count('a')
e = (palavra).count('e')
i = (palavra).count('i')
o = (palavra).count('o')
u = (palavra).count('u')

def conta_vogais(vogais):
    vogais = a + e + i + o + u
    return vogais

vogais
# Out:
# 5

# %% [markdown]
# Escreva uma função que solicite a idade de uma pessoa e imprima se ela é criança, adolescente, adulta ou idosa.

# %% [markdown]
# Considere as seguintes faixas etárias:
# - Criança: até 12 anos
# - Adolescente: de 13 a 17 anos
# - Adulto: de 18 a 59 anos
# - Idoso: 60 anos ou mais

# %%
def faixa(idade):
    idade = int(input('Digite sua idade: '))
    if idade <= 12:
        return print('Você é criança!')
    elif 13 < idade <= 17:
        return print('Você é adolescente!')
    elif 18 < idade <= 59:
        return print('Você é adulto!')
    elif idade > 60:
        return print('Você é idoso!')
        
faixa(idade)
# Out:
# Você é idoso!

# %% [markdown]
# Crie uma função chamada fibonacci que recebe um número inteiro n e retorna o n-ésimo número da sequência de Fibonacci. Utilize recursão para resolver o problema.

# %%
n = int(input('Digite um número inteiro: '))

def fibonacci(n):
    if n <= 0:
        return print('O número precisa ser positivo!')
    elif n == 1:
        return 0
    elif n ==2:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)
    
fibonacci(n)
# Out:
# 2
