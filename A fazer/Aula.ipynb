# %% [markdown]
# ![Growdev](https://www.growdev.com.br/assets/images/logo_growdev.png)

# %% [markdown]
# # Tópicos da Aula de Hoje

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/e/ed/Pandas_logo.svg/2560px-Pandas_logo.svg.png" width="500" height="200" />
#
# - Introdução ao Pandas
# - Series

# %% [markdown]
# **Bora pra aula?**

# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.6 MB 7.0 MB/s eta 0:00:02
#     --------------------------------------- 0.2/11.6 MB 2.5 MB/s eta 0:00:05
#    - -------------------------------------- 0.6/11.6 MB 5.0 MB/s eta 0:00:03
#    --- ------------------------------------ 0.9/11.6 MB 5.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/11.6 MB 6.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.6 MB 6.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.9/11.6 MB 6.9 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.6 MB 6.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.6 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.0/11.6 MB 6.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.6 MB 6.8 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %% [markdown]
# # Pandas

# %% [markdown]
# A biblioteca Pandas é uma das ferramentas mais poderosas e amplamente utilizadas para análise e manipulação de dados em Python. Desenvolvida por Wes McKinney, Pandas fornece estruturas de dados flexíveis e eficientes que facilitam o trabalho com dados rotulados e estruturados.
#
# **Por que Usar Pandas?**
# - **Versatilidade**: Pandas é adequado para uma ampla gama de tarefas de manipulação de dados, desde análise exploratória até limpeza e transformação de dados.
# - **Integração**: Trabalha bem com outras bibliotecas Python, como NumPy, Matplotlib e Scikit-Learn, tornando-o uma escolha natural para workflows da área de dados.
# - **Eficiência**: Pandas é otimizado para desempenho e pode lidar com grandes volumes de dados de maneira eficiente.

# %% [markdown]
# [Documentação](https://pandas.pydata.org)<br>
# [Código](https://github.com/pandas-dev/pandas)

# %% [markdown]
# # Series

# %% [markdown]
# A Series é o objeto base do Pandas.

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
lista = [1,2,3]

# %% [markdown]
# Series do Pandas retorna um formato vertical (Coluna).

# %% [markdown]
# Podemos construir `Series` partindo do zero. A forma geral de fazer isso é a seguinte:
#
# ```python
# pd.Series(data, index = index)
# ```
# `index` é um argumento opcional e `data` pode ser várias coisas

# %%
pd.Series(5, index = [1, 2, 6])
# Out:
# 1    5
# 2    5
# 6    5
# dtype: int64

# %%
# Dicionário
dict_exemplo = {2:'a',
                1:'b',
                3:'c'}
dict_exemplo
# Out:
# {2: 'a', 1: 'b', 3: 'c'}

# %%
pd.Series(dict_exemplo).reset_index(drop=True)#.sort_values('index')#.set_index('index')
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
# Criando uma série
s = pd.Series([1, 3, 5, 7, 9])
print(s)
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
s[2]
# Out:
# 5

# %%
# Selecionando um elemento da série
print(s[2])
# Out:
# 5

# %%
s
# Out:
# 0    1
# 1    3
# 2    5
# 3    7
# 4    9
# dtype: int64

# %%
# Adicionando um novo elemento à série
s[5] = 11
s
# Out:
# 0     1
# 1     3
# 2     5
# 3     7
# 4     9
# 5    11
# dtype: int64

# %%
# Removendo um elemento da série
s = s.drop(2)
s
# Out:
# 0     1
# 1     3
# 3     7
# 4     9
# 5    11
# dtype: int64

# %% [markdown]
# ## Operações Básicas com Series

# %%
series1 = pd.Series([1,2,3], index=['carne', 'carneiro', 'ovelha'])
series2 = pd.Series([2,3,4], index=['ovo', 'carneiro', 'ovelha'])

# %%
series1
# Out:
# carne       1
# carneiro    2
# ovelha      3
# dtype: int64

# %%
series2
# Out:
# ovo         2
# carneiro    3
# ovelha      4
# dtype: int64

# %%
# Soma
series1 + series2
# Out:
# carne       NaN
# carneiro    5.0
# ovelha      7.0
# ovo         NaN
# dtype: float64

# %%
# Divisão
series1/series2
#(series1/series2).round(2)
# Out:
# carne            NaN
# carneiro    0.666667
# ovelha      0.750000
# ovo              NaN
# dtype: float64

# %%
# Subtração
series1 - series2
# Out:
# carne       NaN
# carneiro   -1.0
# ovelha     -1.0
# ovo         NaN
# dtype: float64

# %%
# Multiplicação
series1*series2
# Out:
# carne        NaN
# carneiro     6.0
# ovelha      12.0
# ovo          NaN
# dtype: float64

# %% [markdown]
# ## Outras possibilidades com Series

# %%
series1
# Out:
# carne       1
# carneiro    2
# ovelha      3
# dtype: int64

# %%
series1.sum()
# Out:
# 6

# %%
series1.std()
# Out:
# 1.0

# %%
series1.max()
# Out:
# 3

# %%
series1.min()
# Out:
# 1

# %%
series1.unique()
# Out:
# array([1, 2, 3])

# %%
series1.nunique()
# Out:
# 3

# %%
series1
# Out:
# carne       1
# carneiro    2
# ovelha      3
# dtype: int64

# %%
series1 = pd.Series([1,2,3, 1, 3], index=['carne', 'carneiro', 'ovelha', 'boi', 'touro'])
series1
# Out:
# carne       1
# carneiro    2
# ovelha      3
# boi         1
# touro       3
# dtype: int64

# %%
series1.value_counts()
# Out:
# 1    2
# 3    2
# 2    1
# Name: count, dtype: int64

# %%
series2
# Out:
# ovo         2
# carneiro    3
# ovelha      4
# dtype: int64

# %%
series1
# Out:
# carne       1
# carneiro    2
# ovelha      3
# boi         1
# touro       3
# dtype: int64

# %%
#isin
series1.isin(series2)
# Out:
# carne       False
# carneiro     True
# ovelha       True
# boi         False
# touro        True
# dtype: bool

# %% [markdown]
# # Exercícios

# %% [markdown]
# Dada uma Series com categorias de produtos e suas quantidades vendidas ao longo de uma semana, você deve calcular a frequência de cada categoria e preencher as categorias ausentes com uma quantidade média ajustada. Se uma categoria aparece menos de 3 vezes na semana, substitua suas quantidades por uma média ajustada com base nas categorias mais frequentes.
#
# **Tarefas:**
# - Calcule a frequência de cada categoria na Series data.
# - Identifique as categorias que aparecem menos de 3 vezes e calcule a média das quantidades das categorias mais frequentes.
# - Substitua as quantidades das categorias menos frequentes com a média ajustada calculada.
# - Retorne a Series resultante com as categorias e suas quantidades ajustadas.

# %%
import numpy as np
index = ['Dia 1', 'Dia 2', 'Dia 3', 'Dia 4', 'Dia 5', 'Dia 6', 'Dia 7']
colunas = ['Carne', 'Frango', 'Peixe', 'Porco', 'Feijão', 'Arroz', 'Macarrão']
data = np.random.randint(0, 2, size=(7, 7))


df_mercado = pd.DataFrame(data=data, index=index, columns=colunas)
df_mercado
# Out:
#        Carne  Frango  Peixe  Porco  Feijão  Arroz  Macarrão
# Dia 1      1       0      0      0       1      1         0
# Dia 2      0       1      0      0       0      1         0
# Dia 3      1       0      1      1       1      1         0
# Dia 4      0       1      1      0       0      1         1
# Dia 5      0       0      1      1       1      0         0
# Dia 6      0       0      1      1       0      0         1
# Dia 7      1       1      1      1       1      1         0

# %%
df_mercado.sum()
# Out:
# Carne       3
# Frango      3
# Peixe       5
# Porco       4
# Feijão      4
# Arroz       5
# Macarrão    2
# dtype: int64

# %%
df_mercado['Carne'].mean()
# Out:
# np.float64(0.42857142857142855)

# %%
df_mercado['Media'] =df_mercado.mean()
df_mercado
# Out:
#        Carne  Frango  Peixe  Porco  Feijão  Arroz  Macarrão  Media
# Dia 1      1       0      0      0       1      1         0    NaN
# Dia 2      0       1      0      0       0      1         0    NaN
# Dia 3      1       0      1      1       1      1         0    NaN
# Dia 4      0       1      1      0       0      1         1    NaN
# Dia 5      0       0      1      1       1      0         0    NaN
# Dia 6      0       0      1      1       0      0         1    NaN
# Dia 7      1       1      1      1       1      1         0    NaN

# %%
pd.read_csv('A fazer\#,Comida,Vezes,Dia_da_semana.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[184], line 1
# ----> 1 pd.read_csv('A fazer\#,Comida,Vezes,Dia_da_semana.txt')
#
# ...
