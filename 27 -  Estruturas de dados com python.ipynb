# %% [markdown]
# ![Growdev](https://www.growdev.com.br/assets/images/logo_growdev.png)

# %% [markdown]
# Exercícios:

# %% [markdown]
# 1 - Crie uma lista com 5 números inteiros. Em seguida, escreva um programa que exiba:
#
# - O maior número da lista.
# - O menor número da lista.
# - A soma de todos os números da lista.

# %%
lista = [0, 2, 3, 4, 6]
print('O maior número é: ', max (lista), ' O menor número é: ', min (lista), 'A soma da lista é: ', sum (lista))
# Out:
# O maior número é:  6  O menor número é:  0 A soma da lista é:  15

# %% [markdown]
# 2 - Escreva um programa que solicite ao usuário 5 números e os adicione a um conjunto (set). No final, exiba todos os números, garantindo que não haja repetições.

# %%
i = 0
lista = []
while i < 5:
    set1 = [int(item) for item in input('Digite um número: ')]
    for x in set1:
        lista.append(x)
    i += 1
print(set(lista))
# Out:
# {1, 2, 3}

# %%
numeros = set()

for _ in range (5):
    num = int(input('Digite um número: '))
    numeros.add(num)

print(numeros)
# Out:
# {1, 2, 3}

# %% [markdown]
# 3 - Crie uma tupla com o nome de 5 frutas. Escreva um programa que:
#
# - Imprima a tupla completa.
# - Imprima a fruta na primeira posição.
# - Verifique se a fruta "banana" está presente na tupla.

# %%
tupla = ('Banana', 'Maçã', 'Kiwi', 'Mamão', 'Abacate')
print(tupla)
print(tupla[0])
if 'Banana' in tupla:
    print('Banana está na lista')
else:
    print('Banana não está na lista')
# Out:
# ('Banana', 'Maçã', 'Kiwi', 'Mamão', 'Abacate')
# Banana
# Banana está na lista

# %% [markdown]
# 4 - Crie um dicionário que armazena o nome de 3 pessoas e suas idades. Escreva um programa que:
#
# - Imprima o dicionário completo.
# - Imprima apenas as idades.
# - Adicione uma nova pessoa e sua idade ao dicionário.

# %%
listagem_dicionario = {
    'Fernando' : 27,
    'Ilana' : 25,
    'Julia' : 25
}

print(listagem_dicionario)

print(listagem_dicionario.values())


listagem_dicionario['Roberto'] = 32

print(listagem_dicionario)
# Out:
# {'Fernando': 27, 'Ilana': 25, 'Julia': 25}
# dict_values([27, 25, 25])
# {'Fernando': 27, 'Ilana': 25, 'Julia': 25, 'Roberto': 32}
